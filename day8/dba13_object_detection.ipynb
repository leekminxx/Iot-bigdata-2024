# %% [markdown]
# ### 객체탐지
#
# #### 개요
# - 딥러닝의 CNN(외 RCNN 등)와 같은 알고리즘을 통해서 물체를 인식하여 표시하는 기술
# - 자동차번호판 번호 인식, 화재경보, 교통사고인지, 이상행동파악 등...
# - CCTV과 같이 접목해서 활용되는 경우가 아주 많음

# %% [markdown]
# #### 필요 라이브러리
# - OpenCV - 최초 인텔에서 개발한 오픈소스 실시간 컴퓨터 비전 라이브러리
#     - C/C++을 목표로 제작. 크로스 플랫폼
#     - 파이썬에 OpenCV가 적용되면서 활성화!
#     - 카메라 인식 산업에서 대부분 사용되고 있음
#     - C/C++에서 기본 동작코드 2~300줄이면 파이썬에선 10줄이내로 같은 작업을 할 수 있음
#
# - YOLO(PyTorch)
#     - Not You Only Live Once, You Only Look Once!
#     - 손쉽게 사용할 수 있는 실시간 객체 탐시 시스템
#     - 2015년에 출시후 현재 2024년 현재 v8.0
#     - OpenCV만 가지고 작업하던 걸, YOLO로 넘어가는 추세

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\dev\langs\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\dev\langs\python312\lib\site-packages (from opencv-python) (1.26.3)

# %%
## Window, Mac 차이가 없음
## Raspbarry Pi는 최선버전에서 사용법이 변경되었음.
import cv2

# %%
## 이미지 로드
## 사막여우 == Fennec Fox
img = cv2.imread('./fennec_fox.png')

cv2.imshow('Fox', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
## 현재 웹캠이 동작 안함
video_path = './Mumbai_traffic.mp4'

cap = cv2.VideoCapture(video_path) # 0~숫자는 카메라번호
cap.set(3, 640)
cap.set(4, 480)

while (cap.isOpened()):  ## True => (cap.isOpened())
    ret, img = cap.read() # 실시간으로 화면을 캡쳐 ret(결과정보객체), img(실시간이미지)
    if ret == True:
        cv2.imshow('youtube mpeg', img) ## 내부적으로 PyQt로 생성되는 GUI창

        if cv2.waitKey(1) == ord('q'): # 키보드 q를 클릭하면
            break
    else:
        break

cap.release() # 자원 해제
cv2.destroyAllWindows()

# %% [markdown]
# ##### 이미지 처리

# %%
img = cv2.imread('./fennec_fox.png')

cv2.imshow('Original', img) ## 일반 이미지
# cv2.waitKey(0) 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
height, width = img.shape[0], img.shape[1]
## 정수입력 width/2 => float 문제
half_img = cv2.resize(gray, (int(width/2), int(height/2)))
# cv2.imshow('Gray', gray) ## 흑백 변환
cv2.imshow('half', half_img)
cv2.waitKey(0) 

cv2.destroyAllWindows()

# %%
video_path = './Mumbai_traffic.mp4'

cap = cv2.VideoCapture(video_path) # 0~숫자는 카메라번호
cap.set(3, 640)
cap.set(4, 480)

while (cap.isOpened()):   
    ret, img = cap.read() # 실시간으로 화면을 캡쳐 ret(결과정보객체) 보통 사용하지 않아서 _로 변경, img(실시간이미지)
    if ret == True:
        # cv2.imshow('youtube mpeg', img) ## 내부적으로 PyQt로 생성되는 GUI창
        height, width = img.shape[0], img.shape[1]
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  ## 컬러 -> 흑백으로
        half = cv2.resize(gray, (int(width/2), int(height/2))) ## 사이즈를 반으로 축소
        cv2.imshow('youtube gray', half)

        if cv2.waitKey(1) == ord('q'): # 키보드 q를 클릭하면
            break
    else:
        break

cap.release() # 자원 해제
cv2.destroyAllWindows()

# %% [markdown]
# - 포토샵등의 이미지, 프리미어등의 동영상 처리하는 프로그램에서 사용하는 거의 대부분의 기능이 OpenCV에 포함되어 있음

# %%
video_path = './mbc_news.mp4'

faceCascade = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(video_path) # 0~숫자는 카메라번호

while (cap.isOpened()):    
    ret, img = cap.read() # 실시간으로 화면을 캡쳐 ret(결과정보객체) 보통 사용하지 않아서 _로 변경, img(실시간이미지)
    if ret == True:
        height, width = img.shape[0], img.shape[1]

        half = cv2.resize(img, (int(width/2), int(height/2)))

        # 얼굴인식
        faces = faceCascade.detectMultiScale(
            half,
            scaleFactor=2.0,
            minNeighbors=5,
            minSize=(10,10)
        )
        ## 찾은 얼굴 위치 표시
        for (x,y,w,h) in faces:
            cv2.rectangle(half,(x,y),(x+w,y+h),(0,255,255), 2)
            roi_color = half[y:y+h, x:x+w]

        cv2.imshow('youtube mpeg', half) ## 내부적으로 PyQt로 생성되는 GUI창

        if cv2.waitKey(1) == ord('q'): # 키보드 q를 클릭하면
            break
    
    else:
        break

cap.release() # 자원 해제
cv2.destroyAllWindows()

# %% [markdown]
# ##### YOLO
# - You Only Look Once - CNN 기반으로 한 물체 감지 라이브러리
# - https://www.ultralytics.com/ko
# - https://github.com/ultralytics/ultralytics

# %%
# YOlO 설치
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.76-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics) (1.26.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics) (3.8.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\dev\langs\python312\lib\site-packages (from ultralytics) (10.2.0)
# Collecting pyyaml>=5.3.1 (from ultralytics)
#   Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: requests>=2.23.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics) (2.31.0)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Downloading scipy-1.14.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.4.0-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.19.0-1-cp312-cp312-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in c:\users\user\appdata\roaming\python\python312\site-packages (from ultralytics) (5.9.8)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in c:\dev\langs\python312\lib\site-packages (from ultralytics) (2.2.0)
# Requirement already satisfied: seaborn>=0.11.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\langs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\dev\langs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\langs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dev\langs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\langs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\dev\langs\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\dev\langs\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\dev\langs\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\dev\langs\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\dev\langs\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\dev\langs\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2023.11.17)
# Requirement already satisfied: filelock in c:\dev\langs\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\dev\langs\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Collecting sympy (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in c:\dev\langs\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in c:\dev\langs\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (69.1.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python312\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\dev\langs\python312\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.4)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.8.0->ultralytics)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading ultralytics-8.2.76-py3-none-any.whl (865 kB)
#    ---------------------------------------- 0.0/865.6 kB ? eta -:--:--
#    ---------------------------------------- 865.6/865.6 kB 4.8 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Downloading scipy-1.14.0-cp312-cp312-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    - -------------------------------------- 1.6/44.5 MB 8.4 MB/s eta 0:00:06
#    --- ------------------------------------ 3.7/44.5 MB 9.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.8/44.5 MB 9.8 MB/s eta 0:00:04
#    ------- -------------------------------- 8.4/44.5 MB 10.4 MB/s eta 0:00:04
#    --------- ------------------------------ 10.5/44.5 MB 10.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 12.1/44.5 MB 10.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 12.1/44.5 MB 10.8 MB/s eta 0:00:04
#    ------------ --------------------------- 13.9/44.5 MB 8.6 MB/s eta 0:00:04
#    -------------- ------------------------- 16.0/44.5 MB 8.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 18.4/44.5 MB 9.1 MB/s eta 0:00:03
#    ------------------ --------------------- 20.7/44.5 MB 9.3 MB/s eta 0:00:03
#    -------------------- ------------------- 23.3/44.5 MB 9.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 25.7/44.5 MB 9.7 MB/s eta 0:00:02
#    ------------------------- -------------- 28.0/44.5 MB 9.9 MB/s eta 0:00:02
#    --------------------------- ------------ 30.4/44.5 MB 10.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 32.8/44.5 MB 10.1 MB/s eta 0:00:02
#    ------------------------------- -------- 35.1/44.5 MB 10.2 MB/s eta 0:00:01
#    --------------------------------- ------ 37.5/44.5 MB 10.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.8/44.5 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------- -- 42.2/44.5 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.5 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 10.0 MB/s eta 0:00:00
# Downloading torch-2.4.0-cp312-cp312-win_amd64.whl (197.8 MB)
#    ---------------------------------------- 0.0/197.8 MB ? eta -:--:--
#    ---------------------------------------- 2.4/197.8 MB 11.2 MB/s eta 0:00:18
#     --------------------------------------- 4.5/197.8 MB 11.2 MB/s eta 0:00:18
#    - -------------------------------------- 6.8/197.8 MB 11.3 MB/s eta 0:00:17
#    - -------------------------------------- 9.4/197.8 MB 11.5 MB/s eta 0:00:17
#    -- ------------------------------------- 11.8/197.8 MB 11.5 MB/s eta 0:00:17
#    -- ------------------------------------- 14.2/197.8 MB 11.5 MB/s eta 0:00:16
#    --- ------------------------------------ 16.5/197.8 MB 11.6 MB/s eta 0:00:16
#    --- ------------------------------------ 18.9/197.8 MB 11.6 MB/s eta 0:00:16
#    ---- ----------------------------------- 21.2/197.8 MB 11.6 MB/s eta 0:00:16
#    ---- ----------------------------------- 23.6/197.8 MB 11.6 MB/s eta 0:00:16
#    ----- ---------------------------------- 25.7/197.8 MB 11.5 MB/s eta 0:00:15
#    ----- ---------------------------------- 28.3/197.8 MB 11.6 MB/s eta 0:00:15
#    ------ --------------------------------- 30.7/197.8 MB 11.6 MB/s eta 0:00:15
#    ------ --------------------------------- 32.8/197.8 MB 11.6 MB/s eta 0:00:15
#    ------- -------------------------------- 35.4/197.8 MB 11.6 MB/s eta 0:00:15
#    ------- -------------------------------- 37.7/197.8 MB 11.6 MB/s eta 0:00:14
#    -------- ------------------------------- 40.1/197.8 MB 11.6 MB/s eta 0:00:14
#    -------- ------------------------------- 42.5/197.8 MB 11.6 MB/s eta 0:00:14
#    -------- ------------------------------- 43.8/197.8 MB 11.3 MB/s eta 0:00:14
#    --------- ------------------------------ 46.4/197.8 MB 11.4 MB/s eta 0:00:14
#    --------- ------------------------------ 48.5/197.8 MB 11.3 MB/s eta 0:00:14
#    ---------- ----------------------------- 50.9/197.8 MB 11.4 MB/s eta 0:00:13
#    ---------- ----------------------------- 51.9/197.8 MB 11.1 MB/s eta 0:00:14
#    ---------- ----------------------------- 51.9/197.8 MB 11.1 MB/s eta 0:00:14
#    ---------- ----------------------------- 52.2/197.8 MB 10.3 MB/s eta 0:00:15
#    ----------- ---------------------------- 54.5/197.8 MB 10.3 MB/s eta 0:00:14
#    ----------- ---------------------------- 56.9/197.8 MB 10.4 MB/s eta 0:00:14
#    ----------- ---------------------------- 59.0/197.8 MB 10.3 MB/s eta 0:00:14
#    ------------ --------------------------- 61.3/197.8 MB 10.4 MB/s eta 0:00:14
#    ------------ --------------------------- 63.7/197.8 MB 10.4 MB/s eta 0:00:13
#    ------------- -------------------------- 66.1/197.8 MB 10.5 MB/s eta 0:00:13
#    ------------- -------------------------- 68.4/197.8 MB 10.5 MB/s eta 0:00:13
#    -------------- ------------------------- 69.5/197.8 MB 10.5 MB/s eta 0:00:13
#    -------------- ------------------------- 69.5/197.8 MB 10.5 MB/s eta 0:00:13
#    -------------- ------------------------- 71.0/197.8 MB 10.0 MB/s eta 0:00:13
#    -------------- ------------------------- 73.4/197.8 MB 10.0 MB/s eta 0:00:13
#    --------------- ------------------------ 75.8/197.8 MB 10.0 MB/s eta 0:00:13
#    --------------- ------------------------ 77.1/197.8 MB 10.1 MB/s eta 0:00:12
#    --------------- ------------------------ 77.1/197.8 MB 10.1 MB/s eta 0:00:12
#    --------------- ------------------------ 78.4/197.8 MB 9.6 MB/s eta 0:00:13
#    ---------------- ----------------------- 80.2/197.8 MB 9.6 MB/s eta 0:00:13
#    ---------------- ----------------------- 81.8/197.8 MB 9.6 MB/s eta 0:00:13
#    ---------------- ----------------------- 83.4/197.8 MB 9.5 MB/s eta 0:00:13
#    ----------------- ---------------------- 86.0/197.8 MB 9.6 MB/s eta 0:00:12
#    ----------------- ---------------------- 88.1/197.8 MB 9.6 MB/s eta 0:00:12
#    ------------------ --------------------- 90.2/197.8 MB 9.6 MB/s eta 0:00:12
#    ------------------ --------------------- 91.2/197.8 MB 9.5 MB/s eta 0:00:12
#    ------------------ --------------------- 92.0/197.8 MB 9.5 MB/s eta 0:00:12
#    ------------------- -------------------- 94.1/197.8 MB 9.4 MB/s eta 0:00:12
#    ------------------- -------------------- 95.9/197.8 MB 9.4 MB/s eta 0:00:11
#    ------------------- -------------------- 97.5/197.8 MB 9.4 MB/s eta 0:00:11
#    ------------------- -------------------- 98.8/197.8 MB 9.3 MB/s eta 0:00:11
#    -------------------- ------------------- 100.4/197.8 MB 9.3 MB/s eta 0:00:11
#    -------------------- ------------------- 101.7/197.8 MB 9.2 MB/s eta 0:00:11
#    -------------------- ------------------- 103.8/197.8 MB 9.2 MB/s eta 0:00:11
#    --------------------- ------------------ 105.9/197.8 MB 9.3 MB/s eta 0:00:10
#    --------------------- ------------------ 108.3/197.8 MB 9.3 MB/s eta 0:00:10
#    --------------------- ------------------ 108.8/197.8 MB 9.3 MB/s eta 0:00:10
#    --------------------- ------------------ 108.8/197.8 MB 9.3 MB/s eta 0:00:10
#    ---------------------- ----------------- 110.9/197.8 MB 9.1 MB/s eta 0:00:10
#    ---------------------- ----------------- 113.2/197.8 MB 9.1 MB/s eta 0:00:10
#    ----------------------- ---------------- 115.6/197.8 MB 9.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 116.1/197.8 MB 9.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 118.2/197.8 MB 9.1 MB/s eta 0:00:09
#    ------------------------ --------------- 120.6/197.8 MB 9.1 MB/s eta 0:00:09
#    ------------------------ --------------- 122.9/197.8 MB 9.1 MB/s eta 0:00:09
#    ------------------------- -------------- 125.3/197.8 MB 9.2 MB/s eta 0:00:08
#    ------------------------- -------------- 126.1/197.8 MB 9.2 MB/s eta 0:00:08
#    ------------------------- -------------- 128.2/197.8 MB 9.1 MB/s eta 0:00:08
#    -------------------------- ------------- 130.5/197.8 MB 9.1 MB/s eta 0:00:08
#    -------------------------- ------------- 132.9/197.8 MB 9.2 MB/s eta 0:00:08
#    --------------------------- ------------ 134.5/197.8 MB 9.2 MB/s eta 0:00:07
#    --------------------------- ------------ 134.5/197.8 MB 9.2 MB/s eta 0:00:07
#    --------------------------- ------------ 136.1/197.8 MB 9.0 MB/s eta 0:00:07
#    --------------------------- ------------ 138.4/197.8 MB 9.0 MB/s eta 0:00:07
#    ---------------------------- ----------- 140.5/197.8 MB 9.0 MB/s eta 0:00:07
#    ---------------------------- ----------- 143.1/197.8 MB 9.1 MB/s eta 0:00:07
#    ---------------------------- ----------- 143.1/197.8 MB 9.1 MB/s eta 0:00:07
#    ----------------------------- ---------- 145.0/197.8 MB 9.0 MB/s eta 0:00:06
#    ----------------------------- ---------- 147.6/197.8 MB 9.0 MB/s eta 0:00:06
#    ------------------------------ --------- 149.7/197.8 MB 9.1 MB/s eta 0:00:06
#    ------------------------------ --------- 152.0/197.8 MB 9.1 MB/s eta 0:00:06
#    ------------------------------- -------- 154.4/197.8 MB 9.1 MB/s eta 0:00:05
#    ------------------------------- -------- 157.0/197.8 MB 9.1 MB/s eta 0:00:05
#    -------------------------------- ------- 159.4/197.8 MB 9.2 MB/s eta 0:00:05
#    -------------------------------- ------- 161.7/197.8 MB 9.2 MB/s eta 0:00:04
#    -------------------------------- ------- 163.1/197.8 MB 9.2 MB/s eta 0:00:04
#    --------------------------------- ------ 164.9/197.8 MB 9.2 MB/s eta 0:00:04
#    --------------------------------- ------ 167.2/197.8 MB 9.2 MB/s eta 0:00:04
#    ---------------------------------- ----- 169.6/197.8 MB 9.2 MB/s eta 0:00:04
#    ---------------------------------- ----- 172.0/197.8 MB 9.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 174.3/197.8 MB 9.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 176.7/197.8 MB 9.3 MB/s eta 0:00:03
#    ------------------------------------ --- 179.0/197.8 MB 9.3 MB/s eta 0:00:03
#    ------------------------------------ --- 181.4/197.8 MB 9.4 MB/s eta 0:00:02
#    ------------------------------------- -- 184.0/197.8 MB 9.4 MB/s eta 0:00:02
#    ------------------------------------- -- 186.4/197.8 MB 9.4 MB/s eta 0:00:02
#    -------------------------------------- - 188.0/197.8 MB 9.4 MB/s eta 0:00:02
#    -------------------------------------- - 189.8/197.8 MB 9.4 MB/s eta 0:00:01
#    -------------------------------------- - 192.4/197.8 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  194.8/197.8 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  197.1/197.8 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  197.7/197.8 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 197.8/197.8 MB 9.3 MB/s eta 0:00:00
# Downloading torchvision-0.19.0-1-cp312-cp312-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 10.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 10.2 MB/s eta 0:00:00
# Downloading sympy-1.13.2-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --------------- ------------------------ 2.4/6.2 MB 11.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 11.1 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: py-cpuinfo, mpmath, sympy, scipy, pyyaml, networkx, fsspec, torch, ultralytics-thop, torchvision, ultralytics
# Successfully installed fsspec-2024.6.1 mpmath-1.3.0 networkx-3.3 py-cpuinfo-9.0.0 pyyaml-6.0.2 scipy-1.14.0 sympy-1.13.2 torch-2.4.0 torchvision-0.19.0 ultralytics-8.2.76 ultralytics-thop-2.0.0

# %%
## 콘솔창에서 테스트하는 방법
# !yolo predict model=yolov8s.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt to 'yolov8s.pt'...
# Ultralytics YOLOv8.2.76 🚀 Python-3.11.9 torch-2.4.0+cu124 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# YOLOv8s summary (fused): 168 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 c:\Sources\Iot-bigdata-2024\day8\bus.jpg: 640x480 4 persons, 1 bus, 28.7ms
# Speed: 2.7ms preprocess, 28.7ms inference, 65.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
#   0%|          | 0.00/21.5M [00:00<?, ?B/s]
#   6%|▌         | 1.25M/21.5M [00:00<00:01, 12.5MB/s]
#  12%|█▏        | 2.50M/21.5M [00:00<00:01, 12.1MB/s]
#  17%|█▋        | 3.75M/21.5M [00:00<00:01, 12.0MB/s]
#  23%|██▎       | 5.00M/21.5M [00:00<00:01, 11.9MB/s]
#  29%|██▉       | 6.25M/21.5M [00:00<00:01, 11.8MB/s]
#  35%|███▍      | 7.50M/21.5M [00:00<00:01, 11.9MB/s]
#  41%|████      | 8.75M/21.5M [00:00<00:01, 11.8MB/s]
#  46%|████▋     | 10.0M/21.5M [00:00<00:01, 11.8MB/s]
#  52%|█████▏    | 11.2M/21.5M [00:00<00:00, 11.7MB/s]
#  57%|█████▋    | 12.4M/21.5M [00:01<00:00, 11.7MB/s]
#  63%|██████▎   | 13.5M/21.5M [00:01<00:00, 11.6MB/s]
#  68%|██████▊   | 14.8M/21.5M [00:01<00:00, 11.7MB/s]
#  74%|███████▎  | 15.9M/21.5M [00:01<00:00, 11.7MB/s]
#  79%|███████▉  | 17.0M/21.5M [00:01<00:00, 11.7MB/s]
#  84%|████████▍ | 18.1M/21.5M [00:01<00:00, 11.7MB/s]
#  89%|████████▉ | 19.2M/21.5M [00:01<00:00, 11.6MB/s]
#  95%|█████████▍| 20.4M/21.5M [00:01<00:00, 11.6MB/s]
# 100%|██████████| 21.5M/21.5M [00:01<00:00, 11.7MB/s]
# 100%|██████████| 21.5M/21.5M [00:01<00:00, 11.7MB/s]

# %%
from ultralytics import YOLO

# %%
# 이미지와 openCV 물체감지
model = YOLO(model='./yolov8n.pt')

result = model('./20240812_151755471.jpg')
plots = result[0].plot()
last = cv2.resize(plots, (800, 450))
cv2.imshow('yolo', last)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 11.0MB/s]
# image 1/1 c:\Sources\Iot-bigdata-2024\day8\20240812_151755471.jpg: 384x640 1 bottle, 1 cup, 1 bowl, 1 tv, 1 mouse, 32.4ms
# Speed: 4.0ms preprocess, 32.4ms inference, 75.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       4 result = model('./20240812_151755471.jpg')
#       5 plots = result[0].plot()
# ----> 6 last = cv2.resize(plots, (800, 450))
#       7 cv2.imshow('yolo', last)
#       8 cv2.waitKey(0)
#
# NameError: name 'cv2' is not defined

# %%
# !pip install git+https://github.com/ultralytics/ultralytics.git@main
# Out:
# Collecting git+https://github.com/ultralytics/ultralytics.git@main
#   Cloning https://github.com/ultralytics/ultralytics.git (to revision main) to c:\users\user\appdata\local\temp\pip-req-build-ri2pcmja
#   Resolved https://github.com/ultralytics/ultralytics.git to commit 63e26e1fc8a2f96199c9ae6ecb26c13ba880a072
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (1.26.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (3.8.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (1.14.0)
# Requirement already satisfied: torch>=1.8.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (4.66.4)
# Requirement already satisfied: psutil in c:\users\user\appdata\roaming\python\python312\site-packages (from ultralytics==8.2.76) (5.9.8)
# Requirement already satisfied: py-cpuinfo in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (2.2.0)
# Requirement already satisfied: seaborn>=0.11.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\dev\langs\python312\lib\site-packages (from ultralytics==8.2.76) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\langs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.2.76) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\dev\langs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.2.76) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\langs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.2.76) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dev\langs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.2.76) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics==8.2.76) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\langs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics==8.2.76) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics==8.2.76) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\dev\langs\python312\lib\site-packages (from pandas>=1.1.4->ultralytics==8.2.76) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\dev\langs\python312\lib\site-packages (from pandas>=1.1.4->ultralytics==8.2.76) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\dev\langs\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.2.76) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\dev\langs\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.2.76) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\dev\langs\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.2.76) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\dev\langs\python312\lib\site-packages (from requests>=2.23.0->ultralytics==8.2.76) (2023.11.17)
# Requirement already satisfied: filelock in c:\dev\langs\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.2.76) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\dev\langs\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.2.76) (4.9.0)
# Requirement already satisfied: sympy in c:\dev\langs\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.2.76) (1.13.2)
# Requirement already satisfied: networkx in c:\dev\langs\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.2.76) (3.3)
# Requirement already satisfied: jinja2 in c:\dev\langs\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.2.76) (3.1.3)
# Requirement already satisfied: fsspec in c:\dev\langs\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.2.76) (2024.6.1)
# Requirement already satisfied: setuptools in c:\dev\langs\python312\lib\site-packages (from torch>=1.8.0->ultralytics==8.2.76) (69.1.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python312\site-packages (from tqdm>=4.64.0->ultralytics==8.2.76) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.2.76) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\dev\langs\python312\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics==8.2.76) (2.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\dev\langs\python312\lib\site-packages (from sympy->torch>=1.8.0->ultralytics==8.2.76) (1.3.0)
# Building wheels for collected packages: ultralytics
#   Building wheel for ultralytics (pyproject.toml): started
#   Building wheel for ultralytics (pyproject.toml): finished with status 'done'
#   Created wheel for ultralytics: filename=ultralytics-8.2.76-py3-none-any.whl size=870460 sha256=abb5a28b2e028e259261d9421371028c63a6c16953da8dfd1928e0ea0658f3b4
#   Stored in directory: C:\Users\user\AppData\Local\Temp\pip-ephem-wheel-cache-wzhkp5v8\wheels\bb\0b\bb\3516bf4b0d4c640cfbedf6829f1fa9e8d7dfbcd688eeed795c
# Successfully built ultralytics
# Installing collected packages: ultralytics
# Successfully installed ultralytics-8.2.76
#   Running command git clone --filter=blob:none --quiet https://github.com/ultralytics/ultralytics.git 'C:\Users\user\AppData\Local\Temp\pip-req-build-ri2pcmja'

# %%
## 실시간 가능 , 동영상도 가능
classNames =["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# %%
video_path = './Mumbai_traffic.mp4'

cap = cv2.VideoCapture(video_path) # 0~숫자는 CCTV , 웹캠 등 실시간 영상

while (cap.isOpened()):  
    ret, img = cap.read() 
    if ret == True:
        height, width = img.shape[0], img.shape[1]
        half= cv2.resize(img,(int(width/2) , int(height/2)))
        # YOLO로 물체검출 시작 
        results = model(half, stream = True)

        # 결과표시 like OpenCV 얼굴 검출
        for result in results:
            last = result.plot()
            
        cv2.imshow('YOLOv8' , last)

        if cv2.waitKey(1) == ord('q'): # 키보드 q를 클릭하면
            break
    else:
        break

cap.release() # 자원 해제
cv2.destroyAllWindows()
# Out:
# 0: 384x640 5 persons, 13 cars, 44 airplanes, 4 buss, 6 trains, 60 boats, 4 traffic lights, 5 fire hydrants, 10 stop signs, 7 birds, 2 cats, 6 dogs, 3 horses, 2 sheeps, 4 cows, 13 bears, 2 zebras, 6 giraffes, 12 umbrellas, 1 tie, 1 frisbee, 2 baseball gloves, 1 wine glass, 20 spoons, 8 apples, 1 orange, 3 cakes, 2 couchs, 2 potted plants, 7 beds, 42 dining tables, 2 keyboards, 207.9ms
# Speed: 2.0ms preprocess, 207.9ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 7 bicycles, 20 cars, 1 airplane, 5 buss, 7 trains, 1 truck, 6 boats, 11 traffic lights, 10 fire hydrants, 96 stop signs, 32 parking meters, 1 bench, 7 cows, 2 zebras, 2 umbrellas, 1 handbag, 4 ties, 2 frisbees, 5 sports balls, 1 baseball bat, 1 tennis racket, 2 bottles, 11 wine glasss, 7 forks, 1 spoon, 4 couchs, 10 mouses, 10 remotes, 1 oven, 1 sink, 10 clocks, 2 vases, 161.7ms
# Speed: 4.0ms preprocess, 161.7ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 34 bicycles, 13 cars, 16 motorcycles, 1 bus, 7 trains, 5 trucks, 11 boats, 3 traffic lights, 27 fire hydrants, 55 stop signs, 28 parking meters, 2 birds, 2 dogs, 2 cows, 4 bears, 1 umbrella, 15 handbags, 2 suitcases, 3 frisbees, 7 sports balls, 5 bottles, 2 wine glasss, 1 knife, 8 spoons, 3 bowls, 2 bananas, 1 apple, 1 hot dog, 5 donuts, 1 cake, 1 couch, 2 beds, 1 toilet, 16 remotes, 1 keyboard, 1 oven, 1 sink, 4 clocks, 1 vase, 2 hair driers, 157.4ms
# Speed: 2.6ms preprocess, 157.4ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 11 bicycles, 33 cars, 17 motorcycles, 11 airplanes, 14 buss, 6 trains, 9 trucks, 17 boats, 3 traffic lights, 7 fire hydrants, 19 stop signs, 8 parking meters, 30 dogs, 26 horses, 1 sheep, 5 cows, 2 elephants, 4 bears, 3 zebras, 2 giraffes, 2 backpacks, 2 umbrellas, 3 handbags, 3 ties, 8 skiss, 1 snowboard, 8 surfboards, 1 wine glass, 4 forks, 5 spoons, 1 pizza, 1 couch, 1 bed, 1 dining table, 3 mouses, 1 cell phone, 1 clock, 155.3ms
# Speed: 2.5ms preprocess, 155.3ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 12 bicycles, 5 cars, 4 motorcycles, 3 airplanes, 26 trains, 19 boats, 2 fire hydrants, 5 stop signs, 3 parking meters, 6 benchs, 5 dogs, 2 horses, 9 bears, 1 giraffe, 1 backpack, 104 umbrellas, 4 handbags, 7 suitcases, 14 frisbees, 20 skiss, 3 snowboards, 3 knifes, 9 spoons, 2 apples, 4 beds, 15 dining tables, 2 remotes, 7 keyboards, 1 toothbrush, 153.3ms
# Speed: 2.0ms preprocess, 153.3ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 11 airplanes, 6 buss, 40 trains, 1 truck, 93 boats, 7 traffic lights, 4 fire hydrants, 1 parking meter, 1 cat, 2 dogs, 1 horse, 4 cows, 5 bears, 1 zebra, 1 backpack, 5 suitcases, 1 skis, 1 baseball bat, 5 bottles, 77 spoons, 2 couchs, 1 dining table, 1 microwave, 11 ovens, 1 toaster, 2 clocks, 148.0ms
# Speed: 1.0ms preprocess, 148.0ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 28 bicycles, 19 cars, 77 motorcycles, 1 airplane, 6 buss, 28 trains, 6 trucks, 46 boats, 2 traffic lights, 3 fire hydrants, 24 stop signs, 8 parking meters, 1 bench, 2 dogs, 3 horses, 4 bears, 1 zebra, 9 umbrellas, 7 handbags, 3 suitcases, 1 sports ball, 1 bottle, 1 banana, 2 oranges, 1 broccoli, 2 cakes, 1 couch, 1 bed, 5 dining tables, 1 keyboard, 1 oven, 149.4ms
# Speed: 1.0ms preprocess, 149.4ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 cars, 24 motorcycles, 12 airplanes, 3 buss, 20 trains, 3 trucks, 92 boats, 1 traffic light, 5 fire hydrants, 2 stop signs, 1 bench, 2 dogs, 12 horses, 1 bear, 12 umbrellas, 2 handbags, 5 suitcases, 1 frisbee, 3 sports balls, 2 surfboards, 5 bottles, 10 spoons, 1 apple, 2 oranges, 1 cake, 1 couch, 18 beds, 40 dining tables, 1 tv, 1 teddy bear, 145.9ms
# Speed: 2.0ms preprocess, 145.9ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 bicycles, 37 cars, 6 motorcycles, 27 airplanes, 4 buss, 4 trains, 11 trucks, 4 boats, 8 traffic lights, 10 fire hydrants, 8 stop signs, 6 parking meters, 30 benchs, 2 birds, 6 cats, 8 dogs, 14 horses, 1 cow, 13 bears, 3 umbrellas, 3 handbags, 1 tie, 2 suitcases, 3 sports balls, 1 baseball bat, 6 baseball gloves, 2 spoons, 1 bowl, 2 apples, 1 orange, 2 broccolis, 14 couchs, 2 potted plants, 17 beds, 11 dining tables, 11 remotes, 5 cell phones, 1 book, 1 clock, 146.9ms
# Speed: 2.0ms preprocess, 146.9ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 8 bicycles, 13 cars, 22 motorcycles, 9 airplanes, 3 buss, 23 trains, 1 truck, 62 boats, 3 traffic lights, 31 fire hydrants, 18 stop signs, 7 parking meters, 6 benchs, 4 dogs, 18 bears, 1 backpack, 9 umbrellas, 2 handbags, 7 suitcases, 4 frisbees, 1 skis, 3 sports balls, 2 bottles, 3 knifes, 6 spoons, 5 apples, 4 oranges, 1 broccoli, 2 carrots, 1 donut, 1 cake, 4 dining tables, 5 remotes, 6 keyboards, 141.0ms
# Speed: 0.5ms preprocess, 141.0ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 cars, 8 motorcycles, 25 airplanes, 83 boats, 4 traffic lights, 5 fire hydrants, 58 stop signs, 16 parking meters, 2 dogs, 2 horses, 4 handbags, 1 baseball glove, 16 spoons, 3 bananas, 4 apples, 2 oranges, 3 cakes, 2 beds, 31 dining tables, 1 mouse, 3 teddy bears, 152.4ms
# Speed: 1.0ms preprocess, 152.4ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 bicycles, 28 cars, 17 motorcycles, 22 airplanes, 7 trains, 25 boats, 2 fire hydrants, 19 stop signs, 15 benchs, 1 bird, 2 cats, 17 dogs, 2 horses, 1 sheep, 3 cows, 1 elephant, 15 bears, 2 zebras, 10 backpacks, 37 umbrellas, 7 handbags, 8 suitcases, 5 frisbees, 5 knifes, 3 spoons, 1 donut, 7 beds, 21 dining tables, 1 laptop, 1 mouse, 1 remote, 1 keyboard, 1 clock, 145.4ms
# Speed: 2.0ms preprocess, 145.4ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 14 cars, 7 motorcycles, 2 trains, 3 trucks, 26 boats, 1 traffic light, 52 fire hydrants, 41 stop signs, 72 parking meters, 1 bird, 2 dogs, 2 horses, 2 sheeps, 4 bears, 1 backpack, 2 umbrellas, 7 handbags, 6 frisbees, 3 skiss, 2 snowboards, 3 sports balls, 5 bottles, 6 spoons, 1 couch, 22 dining tables, 1 cell phone, 2 teddy bears, 3 hair driers, 161.0ms
# Speed: 2.0ms preprocess, 161.0ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 bicycles, 35 cars, 1 airplane, 1 bus, 6 trains, 32 trucks, 8 boats, 7 traffic lights, 6 fire hydrants, 21 stop signs, 19 parking meters, 2 birds, 3 horses, 14 sheeps, 25 cows, 2 elephants, 26 bears, 61 zebras, 9 giraffes, 2 skiss, 5 cell phones, 3 clocks, 144.5ms
# Speed: 2.0ms preprocess, 144.5ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 bicycles, 9 cars, 47 motorcycles, 40 airplanes, 2 buss, 1 train, 26 boats, 21 traffic lights, 4 fire hydrants, 18 stop signs, 8 parking meters, 6 dogs, 7 horses, 1 elephant, 4 bears, 1 handbag, 1 skis, 4 baseball bats, 1 baseball glove, 2 surfboards, 1 bottle, 29 spoons, 4 apples, 2 broccolis, 1 cake, 3 beds, 35 dining tables, 4 tvs, 1 oven, 147.9ms
# Speed: 1.0ms preprocess, 147.9ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 23 bicycles, 74 cars, 1 motorcycle, 51 airplanes, 4 buss, 17 trains, 12 trucks, 14 boats, 12 traffic lights, 1 fire hydrant, 26 stop signs, 6 parking meters, 2 benchs, 5 cats, 10 dogs, 2 horses, 1 cow, 1 suitcase, 1 skis, 2 surfboards, 1 bowl, 3 couchs, 1 potted plant, 7 beds, 4 dining tables, 148.7ms
# Speed: 1.0ms preprocess, 148.7ms inference, 17.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 bicycles, 2 cars, 2 motorcycles, 28 airplanes, 2 trains, 4 trucks, 87 boats, 1 traffic light, 9 fire hydrants, 16 stop signs, 1 parking meter, 1 bench, 3 birds, 6 dogs, 6 bears, 1 giraffe, 6 umbrellas, 1 frisbee, 3 bottles, 35 spoons, 1 banana, 3 apples, 3 oranges, 3 broccolis, 7 couchs, 21 beds, 23 dining tables, 5 tvs, 2 remotes, 2 keyboards, 1 teddy bear, 145.7ms
# Speed: 1.0ms preprocess, 145.7ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 11 cars, 4 motorcycles, 3 airplanes, 9 buss, 7 trains, 7 trucks, 6 boats, 23 traffic lights, 29 fire hydrants, 21 stop signs, 65 parking meters, 3 benchs, 1 dog, 10 horses, 2 sheeps, 1 cow, 3 bears, 1 umbrella, 1 handbag, 8 suitcases, 2 skiss, 4 sports balls, 1 surfboard, 2 bottles, 2 spoons, 6 bowls, 3 bananas, 1 apple, 4 donuts, 15 couchs, 2 potted plants, 8 beds, 7 dining tables, 4 toilets, 2 tvs, 1 microwave, 7 ovens, 2 toasters, 1 refrigerator, 2 hair driers, 144.9ms
# Speed: 1.0ms preprocess, 144.9ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 motorcycles, 4 airplanes, 4 trains, 15 boats, 5 fire hydrants, 51 stop signs, 17 parking meters, 3 birds, 1 cat, 1 dog, 4 horses, 68 bears, 1 giraffe, 78 umbrellas, 1 handbag, 13 frisbees, 6 sports balls, 1 bottle, 3 knifes, 2 spoons, 1 banana, 1 apple, 1 sandwich, 1 orange, 1 cake, 1 bed, 6 dining tables, 1 keyboard, 1 cell phone, 1 sink, 2 toothbrushs, 151.3ms
# Speed: 1.5ms preprocess, 151.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 3 bicycles, 4 cars, 2 motorcycles, 1 train, 98 boats, 2 traffic lights, 8 fire hydrants, 72 stop signs, 52 parking meters, 1 dog, 1 horse, 3 bears, 1 umbrella, 2 handbags, 2 frisbees, 20 sports balls, 5 bottles, 2 oranges, 1 broccoli, 2 dining tables, 11 remotes, 1 cell phone, 148.3ms
# Speed: 2.0ms preprocess, 148.3ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 11 bicycles, 22 cars, 11 motorcycles, 10 airplanes, 4 buss, 20 trains, 18 boats, 19 fire hydrants, 28 stop signs, 15 parking meters, 4 dogs, 8 horses, 15 bears, 1 backpack, 35 umbrellas, 17 handbags, 2 suitcases, 12 frisbees, 1 skis, 1 baseball glove, 3 knifes, 4 spoons, 1 apple, 1 orange, 1 cake, 1 bed, 9 dining tables, 4 remotes, 4 keyboards, 1 toaster, 1 sink, 1 teddy bear, 144.8ms
# Speed: 1.0ms preprocess, 144.8ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 13 bicycles, 23 cars, 25 motorcycles, 4 airplanes, 9 trains, 4 trucks, 80 boats, 1 traffic light, 18 fire hydrants, 21 stop signs, 11 parking meters, 1 bench, 5 horses, 13 bears, 2 zebras, 12 umbrellas, 3 handbags, 7 suitcases, 10 frisbees, 7 sports balls, 1 surfboard, 7 bottles, 1 spoon, 1 orange, 2 cakes, 1 couch, 2 beds, 2 dining tables, 2 remotes, 3 keyboards, 143.2ms
# Speed: 1.0ms preprocess, 143.2ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 12 bicycles, 16 cars, 27 motorcycles, 9 airplanes, 2 buss, 9 trains, 8 trucks, 12 boats, 3 traffic lights, 43 fire hydrants, 12 stop signs, 9 parking meters, 2 benchs, 2 cats, 9 dogs, 1 horse, 4 cows, 22 bears, 1 giraffe, 6 backpacks, 44 umbrellas, 6 handbags, 1 tie, 5 suitcases, 2 frisbees, 1 sports ball, 6 bottles, 2 spoons, 2 bananas, 2 oranges, 1 bed, 3 dining tables, 1 teddy bear, 1 hair drier, 153.0ms
# Speed: 4.0ms preprocess, 153.0ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 bicycles, 2 cars, 1 motorcycle, 3 airplanes, 7 buss, 79 trains, 14 boats, 4 fire hydrants, 10 stop signs, 2 parking meters, 3 benchs, 2 dogs, 8 horses, 1 elephant, 20 bears, 2 giraffes, 58 umbrellas, 1 tie, 2 frisbees, 5 sports balls, 1 baseball bat, 2 bottles, 11 knifes, 30 spoons, 1 orange, 1 couch, 2 beds, 18 dining tables, 5 keyboards, 1 sink, 1 clock, 151.5ms
# Speed: 2.5ms preprocess, 151.5ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7 bicycles, 27 cars, 7 motorcycles, 9 airplanes, 3 buss, 21 trains, 5 trucks, 59 boats, 10 fire hydrants, 3 stop signs, 38 benchs, 1 bird, 5 cats, 6 dogs, 3 horses, 1 sheep, 1 elephant, 7 backpacks, 2 umbrellas, 11 handbags, 11 suitcases, 2 frisbees, 1 skis, 5 snowboards, 1 surfboard, 6 bottles, 1 knife, 1 spoon, 10 couchs, 12 beds, 5 dining tables, 5 remotes, 6 cell phones, 1 sink, 1 book, 3 clocks, 1 teddy bear, 153.7ms
# Speed: 1.0ms preprocess, 153.7ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
## 영상으로 저장하기 

video_path = './Mumbai_traffic.mp4'

cap = cv2.VideoCapture(video_path) # 0~숫자는 카메라번호
cap.set(3, 640)
cap.set(4, 480)

while (cap.isOpened()):  ## True => (cap.isOpened())
    ret, img = cap.read() # 실시간으로 화면을 캡쳐 ret(결과정보객체), img(실시간이미지)
    if ret == True:
        cv2.imshow('youtube mpeg', img) ## 내부적으로 PyQt로 생성되는 GUI창

        if cv2.waitKey(1) == ord('q'): # 키보드 q를 클릭하면
            break
    else:
        break

cap.release() # 자원 해제
cv2.destroyAllWindows()
